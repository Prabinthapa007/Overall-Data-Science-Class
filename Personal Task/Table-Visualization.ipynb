# %% [markdown]
# # Styler Object and Customising the Display
# Styling and output display customisation should be performed after the data in a `DataFrame` has been processed. The Styler is not dynamically updated if further changes to the `DataFrame` are made. The `DataFrame.style` attribute is a property that returns a `Styler` object. It has a `_repr_html_` method defined on it so it is rendered automatically in Jupyter Notebook.

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [22, 23],
    "floats": [12.23, 1300.45]
})

df.style \
.format(precision=3, thousands=".", decimal=",") \
.format_index(str.upper, axis=1) \
.relabel_index(["row1", "row2"], axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_53a85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53a85_level0_col0" class="col_heading level0 col0" >STRINGS</th>
#       <th id="T_53a85_level0_col1" class="col_heading level0 col1" >INTS</th>
#       <th id="T_53a85_level0_col2" class="col_heading level0 col2" >FLOATS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53a85_level0_row0" class="row_heading level0 row0" >row1</th>
#       <td id="T_53a85_row0_col0" class="data row0 col0" >Adam</td>
#       <td id="T_53a85_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_53a85_row0_col2" class="data row0 col2" >12,230</td>
#     </tr>
#     <tr>
#       <th id="T_53a85_level0_row1" class="row_heading level0 row1" >row2</th>
#       <td id="T_53a85_row1_col0" class="data row1 col0" >Mike</td>
#       <td id="T_53a85_row1_col1" class="data row1 col1" >23</td>
#       <td id="T_53a85_row1_col2" class="data row1 col2" >1.300,450</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Using `Styler` to `manipulate` the display is a useful feature because maintaining the `indexing` and `data values` for other purposes gives greater control. You do not have to overwrite your DataFrame to display it how you like. Here is a more comprehensive example of using the formatting functions whilst still relying on the underlying data for indexing and calculations.

# %%
weather_df = pd.DataFrame(np.random.rand(10, 2)*5,
                          index=pd.date_range(start="2022-01-01", periods=10),
                          columns=["Nepal", "India"])

def rain_condition(v):
    if v < 1.75:
        return "Dry"
    elif v < 2.75:
        return "Rain"
    return "Heavy Rain"

def make_look_good(styler):
    styler.set_caption("Weather Condition")
    styler.format(rain_condition)
    styler.format_index(lambda v: v.strftime("%A"))
    styler.background_gradient(axis=None, vmin=0, vmax=6, cmap='YlGnBu')
    return styler

(weather_df)
# Out:
#                Nepal     India
# 2022-01-01  2.070526  1.767871
# 2022-01-02  2.915653  1.462981
# 2022-01-03  4.541431  2.223032
# 2022-01-04  0.786357  3.532917
# 2022-01-05  3.323395  0.106603
# 2022-01-06  1.849069  4.810259
# 2022-01-07  4.962883  1.200097
# 2022-01-08  4.353830  3.131721
# 2022-01-09  2.941879  3.030472
# 2022-01-10  1.387507  1.229100

# %%
weather_df.loc["2022-01-01": "2022-01-07"].style.pipe(make_look_good)
# Out:
# <style type="text/css">
# #T_6c434_row0_col0 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_6c434_row0_col1 {
#   background-color: #aedfb6;
#   color: #000000;
# }
# #T_6c434_row1_col0 {
#   background-color: #48b9c3;
#   color: #f1f1f1;
# }
# #T_6c434_row1_col1 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_6c434_row2_col0 {
#   background-color: #225ca7;
#   color: #f1f1f1;
# }
# #T_6c434_row2_col1 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_6c434_row3_col0 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_6c434_row3_col1 {
#   background-color: #289cc1;
#   color: #f1f1f1;
# }
# #T_6c434_row4_col0 {
#   background-color: #32a6c2;
#   color: #f1f1f1;
# }
# #T_6c434_row4_col1 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_6c434_row5_col0 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_6c434_row5_col1 {
#   background-color: #234c9f;
#   color: #f1f1f1;
# }
# #T_6c434_row6_col0 {
#   background-color: #24449c;
#   color: #f1f1f1;
# }
# #T_6c434_row6_col1 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# </style>
# <table id="T_6c434">
#   <caption>Weather Condition</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c434_level0_col0" class="col_heading level0 col0" >Nepal</th>
#       <th id="T_6c434_level0_col1" class="col_heading level0 col1" >India</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c434_level0_row0" class="row_heading level0 row0" >Saturday</th>
#       <td id="T_6c434_row0_col0" class="data row0 col0" >Rain</td>
#       <td id="T_6c434_row0_col1" class="data row0 col1" >Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6c434_level0_row1" class="row_heading level0 row1" >Sunday</th>
#       <td id="T_6c434_row1_col0" class="data row1 col0" >Heavy Rain</td>
#       <td id="T_6c434_row1_col1" class="data row1 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_6c434_level0_row2" class="row_heading level0 row2" >Monday</th>
#       <td id="T_6c434_row2_col0" class="data row2 col0" >Heavy Rain</td>
#       <td id="T_6c434_row2_col1" class="data row2 col1" >Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6c434_level0_row3" class="row_heading level0 row3" >Tuesday</th>
#       <td id="T_6c434_row3_col0" class="data row3 col0" >Dry</td>
#       <td id="T_6c434_row3_col1" class="data row3 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6c434_level0_row4" class="row_heading level0 row4" >Wednesday</th>
#       <td id="T_6c434_row4_col0" class="data row4 col0" >Heavy Rain</td>
#       <td id="T_6c434_row4_col1" class="data row4 col1" >Dry</td>
#     </tr>
#     <tr>
#       <th id="T_6c434_level0_row5" class="row_heading level0 row5" >Thursday</th>
#       <td id="T_6c434_row5_col0" class="data row5 col0" >Rain</td>
#       <td id="T_6c434_row5_col1" class="data row5 col1" >Heavy Rain</td>
#     </tr>
#     <tr>
#       <th id="T_6c434_level0_row6" class="row_heading level0 row6" >Friday</th>
#       <td id="T_6c434_row6_col0" class="data row6 col0" >Heavy Rain</td>
#       <td id="T_6c434_row6_col1" class="data row6 col1" >Dry</td>
#     </tr>
#   </tbody>
# </table>
